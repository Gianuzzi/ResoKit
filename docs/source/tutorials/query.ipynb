# %% [markdown]
# # Resokit.query Tutorial
#
#
# This tutorial is a guide to use ResoKit.query package.
# ResoKit.query includes tools to make ASQL or SQL
# queries to the EU and NASA datasets with
# optimized structure.
#
# In this brief tutorial we show how to use it.
#
# ---

# %% [markdown]
# ## Import ResoKit and the necessary packages

# %%
import resokit.query as rquery

# %% [markdown]
# ## Query system
#
# The main function `query_system` performs a specific *query* to either NASA or EU, to retrieve a system (or planet) from the online database.
#
# This function does not support non-exact matches, so the system (or planet) input name must be the same as in the database.
#
# Lest load the Kepler 55 system from NASA database.

# %%
k55 = rquery.query_system("nasa", "Kepler-55")
k55
# Out:
#  Querying nasa database with query: SELECT * FROM ps WHERE (hostname='Kepler-55') AND default_flag=1 AND pl_controv_flag=0
# Executing the query...
# Query executed successfully.
# StaticSystem: 'Kepler-55'
#  Star:
#   Kepler-55
#  Planets:
#   Kepler-55 d
#   Kepler-55 e
#   Kepler-55 f
#   Kepler-55 b
#   Kepler-55 c
# from 'nasa' data source.

# %% [markdown]
# The query result is cached during the session, so it can be re-used if necessary.

# %%
k55 = rquery.query_system("nasa", "Kepler-55")
k55
# Out:
#  Querying nasa database with query: SELECT * FROM ps WHERE (hostname='Kepler-55') AND default_flag=1 AND pl_controv_flag=0
# Using cached previous identic query.
# StaticSystem: 'Kepler-55'
#  Star:
#   Kepler-55
#  Planets:
#   Kepler-55 d
#   Kepler-55 e
#   Kepler-55 f
#   Kepler-55 b
#   Kepler-55 c
# from 'nasa' data source.

# %% [markdown]
# ### Query a Planet
#
# If, instead of a whole system, only a planet is needed, we can set the parameter `planet_name` instead of `star_name`.

# %%
k55c = rquery.query_system("nasa", planet_name="Kepler-55 c")
k55c
# Out:
#  Querying nasa database with query: SELECT * FROM ps WHERE (pl_name='Kepler-55 c') AND default_flag=1 AND pl_controv_flag=0
# Executing the query...
# Query executed successfully.
# StaticSystem: 'Kepler-55'
#  Star:
#   Kepler-55
#  Planet:
#   Kepler-55 c
# from 'nasa' data source.

# %% [markdown]
# Here, a system with the star and only the specified planet is created.

# %% [markdown]
# ### Raw dataframe
#
# Instead of a resokit `StaticSystem`, it is possible to retrieve the raw pandas `DataFrame` (without the ResoKit structure) obtained from the query, setting the parameter `raw=True`.

# %%
k55_raw = rquery.query_system("nasa", star_name="Kepler-55", raw=True)
k55_raw
# Out:
#  Querying nasa database with query: SELECT * FROM ps WHERE (hostname='Kepler-55') AND default_flag=1 AND pl_controv_flag=0
# Using cached previous identic query.
#        pl_name pl_letter   hostname  hd_name  hip_name         tic_id  \
# 0  Kepler-55 b         b  Kepler-55      NaN       NaN  TIC 164884002
# 1  Kepler-55 c         c  Kepler-55      NaN       NaN  TIC 164884002
# 2  Kepler-55 d         d  Kepler-55      NaN       NaN  TIC 164884002
# 3  Kepler-55 f         f  Kepler-55      NaN       NaN  TIC 164884002
# 4  Kepler-55 e         e  Kepler-55      NaN       NaN  TIC 164884002
#
#                         gaia_id  default_flag  \
# 0  Gaia DR2 2105930840143687680             1
# 1  Gaia DR2 2105930840143687680             1
# 2  Gaia DR2 2105930840143687680             1
# 3  Gaia DR2 2105930840143687680             1
# 4  Gaia DR2 2105930840143687680             1
#
#                                           pl_refname  \
# 0  <a refstr=STEFFEN_ET_AL__2013 href=https://ui....
# 1  <a refstr=STEFFEN_ET_AL__2013 href=https://ui....
# 2  <a refstr=ROWE_ET_AL__2014 href=https://ui.ads...
# 3  <a refstr=ROWE_ET_AL__2014 href=https://ui.ads...
# 4  <a refstr=ROWE_ET_AL__2014 href=https://ui.ads...
#
#                                           sy_refname  ... sy_jmagerr1  \
# 0  <a refstr=STASSUN_ET_AL__2019 href=https://ui....  ...       0.031
# 1  <a refstr=STASSUN_ET_AL__2019 href=https://ui....  ...       0.031
# 2  <a refstr=STASSUN_ET_AL__2019 href=https://ui....  ...       0.031
# 3  <a refstr=STASSUN_ET_AL__2019 href=https://ui....  ...       0.031
# 4  <a refstr=STASSUN_ET_AL__2019 href=https://ui....  ...       0.031
#
#    sy_jmagerr2           sy_jmagstr sy_hmag sy_hmagerr1 sy_hmagerr2  \
# 0       -0.031  13.970&plusmn;0.031  13.359        0.03       -0.03
# 1       -0.031  13.970&plusmn;0.031  13.359        0.03       -0.03
# 2       -0.031  13.970&plusmn;0.031  13.359        0.03       -0.03
# 3       -0.031  13.970&plusmn;0.031  13.359        0.03       -0.03
# 4       -0.031  13.970&plusmn;0.031  13.359        0.03       -0.03
#
#             sy_hmagstr sy_kmag  sy_kmagerr1 sy_kmagerr2
# 0  13.359&plusmn;0.030  13.289        0.049      -0.049
# 1  13.359&plusmn;0.030  13.289        0.049      -0.049
# 2  13.359&plusmn;0.030  13.289        0.049      -0.049
# 3  13.359&plusmn;0.030  13.289        0.049      -0.049
# 4  13.359&plusmn;0.030  13.289        0.049      -0.049
#
# [5 rows x 354 columns]

# %% [markdown]
# ## Manual query
#
# Sometimes, a more complex or advance query is needed.
#
# This package provides two functions to help performing this task:
#
# -  `build_query`: Assist in the elaboration of a *query* string.
# -  `execute_query`: Performs the given *query* to the specified database.
#
# It is important to know that these *queries* must follow the each database column-name structure.
#
# For example, if we want to *query* all systems with semimajor-axis lower than $0.01\,au$ of the EU database, we first create the *query* with:

# %%
my_query = rquery.build_query("eu", conditions="semi_major_axis < 0.01")
my_query
# Out:
# 'SELECT * FROM exoplanet.epn_core WHERE semi_major_axis < 0.01'

# %% [markdown]
# And the, we execute it with:

# %%
result = rquery.execute_query("eu", my_query)
result
# Out:
# Executing the query...
# Query executed successfully.
#              granule_uid        granule_gid obs_id dataproduct_type  \
# 0          2S 0918-549 b  exoplanet_catalog   9455               ci
# 1    4FGL J1408.6-2917 b  exoplanet_catalog   9100               ci
# 2           4U 0513-40 b  exoplanet_catalog   9741               ci
# 3           4U 0614+09 b  exoplanet_catalog   9739               ci
# 4           4U 1543-62 b  exoplanet_catalog   9077               ci
# ..                   ...                ...    ...              ...
# 134      XTE J0929-314 b  exoplanet_catalog   9076               ci
# 135     ZTF J0038+2030 b  exoplanet_catalog   7860               ci
# 136     ZTF J1230-2655 b  exoplanet_catalog  10892               ci
# 137    ZTF J1406+1222 Ab  exoplanet_catalog   9281               ci
# 138     ZTF J1828+2308 b  exoplanet_catalog  10893               ci
#
#              target_name target_class  time_min  time_max  \
# 0          2S 0918-549 b    exoplanet       NaN       NaN
# 1    4FGL J1408.6-2917 b    exoplanet       NaN       NaN
# 2           4U 0513-40 b    exoplanet       NaN       NaN
# 3           4U 0614+09 b    exoplanet       NaN       NaN
# 4           4U 1543-62 b    exoplanet       NaN       NaN
# ..                   ...          ...       ...       ...
# 134      XTE J0929-314 b    exoplanet       NaN       NaN
# 135     ZTF J0038+2030 b    exoplanet       NaN       NaN
# 136     ZTF J1230-2655 b    exoplanet       NaN       NaN
# 137    ZTF J1406+1222 Ab    exoplanet       NaN       NaN
# 138     ZTF J1828+2308 b    exoplanet       NaN       NaN
#
#      time_sampling_step_min  time_sampling_step_max  ...  star_metallicity  \
# 0                       NaN                     NaN  ...               NaN
# 1                       NaN                     NaN  ...               NaN
# 2                       NaN                     NaN  ...               NaN
# 3                       NaN                     NaN  ...               NaN
# 4                       NaN                     NaN  ...               NaN
# ..                      ...                     ...  ...               ...
# 134                     NaN                     NaN  ...               NaN
# 135                     NaN                     NaN  ...               NaN
# 136                     NaN                     NaN  ...               NaN
# 137                     NaN                     NaN  ...               NaN
# 138                     NaN                     NaN  ...               NaN
#
#      star_mass  star_radius  star_age  star_teff  magnetic_field  \
# 0        1.400          NaN       NaN        NaN           False
# 1        1.400          NaN       NaN        NaN           False
# 2        1.400          NaN       NaN        NaN           False
# 3        1.400          NaN       NaN        NaN           False
# 4        1.400          NaN       NaN        NaN           False
# ..         ...          ...       ...        ...             ...
# 134      1.400      0.00002       NaN        NaN           False
# 135      0.505      0.01429       8.0    10900.0           False
# 136      0.650      0.01230       NaN    10000.0           False
# 137      1.400      0.00002       NaN        NaN           False
# 138      0.610      0.01310       NaN    15900.0           False
#
#      detected_disc          ra        dec  \
# 0                   140.110341 -55.206809
# 1                   211.851208 -29.806389
# 2                    78.527458 -40.043611
# 3                    94.280652   9.137088
# 4                   236.977500 -62.568333
# ..             ...         ...        ...
# 134                 142.334125 -31.384222
# 135                   9.729167  20.507222
# 136                 187.569125 -26.930928
# 137                 211.734058  12.378722
# 138                 277.203208  23.143997
#
#                                          external_link
# 0      http://exoplanet.eu/catalog/2s_0918_549_b--9455
# 1    http://exoplanet.eu/catalog/4fgl_j1408.6_2917_...
# 2       http://exoplanet.eu/catalog/4u_0513_40_b--9741
# 3       http://exoplanet.eu/catalog/4u_0614_09_b--9739
# 4       http://exoplanet.eu/catalog/4u_1543_62_b--9077
# ..                                                 ...
# 134  http://exoplanet.eu/catalog/xte_j0929_314_b--9076
# 135  http://exoplanet.eu/catalog/ztf_j0038_2030_b--...
# 136  http://exoplanet.eu/catalog/ztf_j1230_2655_b--...
# 137  http://exoplanet.eu/catalog/ztf_j1406_1222_ab-...
# 138  http://exoplanet.eu/catalog/ztf_j1828_2308_b--...
#
# [139 rows x 136 columns]

# %% [markdown]
# The result is given as a raw pandas `DataFrame`.
