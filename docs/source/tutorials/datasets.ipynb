# %% [markdown]
# # Resokit.datasets Tutorial
#
#
# This tutorial is a guide to use ResoKit.datasets package.
# ResoKit.datasets provides tools for loading the available datasets:
# - [NASA](https://exoplanetarchive.ipac.caltech.edu/)
# - [EU](https://exoplanet.eu/home/)
#
# In this tutorial we show, step by step, how to get started with the ResoKit.datasets package.
#
# ---

# %% [markdown]
# ## Import ResoKit and the necessary packages

# %%
import resokit.datasets as datasets

import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the dataset
#
# Let's start with EU catalogue.

# %%
data = datasets.load_eu()
data
# Out:
#  Loading the entire dataset...
#   Reading exoplanet_eu.csv directly from datasets.zip...
# Full ResokitDataset - 7414 rows x 45 columns
# Source: eu
# Age: 12 days
# Origin: zip
#                    name     mass  mass_err_min  mass_err_max  mass_sin_i  \
# 0             109 Psc b   5.7430       0.28900       0.28900      6.3830
# 1             112 Psc b   0.0330       0.00500       0.00500      0.0330
# 2             112 Psc c   9.8660       1.78100       1.78100         NaN
# 3             11 Com Ab  16.1284       1.53491       1.53491     16.1284
# 4              11 UMi b  11.0873       1.10000       1.10000     11.0873
# ...                 ...      ...           ...           ...         ...
# 7409  ZTF J1406+1222 Ab  50.0000           NaN           NaN         NaN
# 7410     ZTF J1622+47 b  61.0000      19.00000      19.00000         NaN
# 7411     ZTF J1637+49 b  23.0000       8.00000       8.00000         NaN
# 7412   ZTF J1828+2308 b  19.5000       0.80000       0.80000         NaN
# 7413     ZTF J2252-05 b  26.0000       8.00000       8.00000         NaN
#
#       mass_sin_i_err_min  mass_sin_i_err_max  radius  radius_err_min  \
# 0                0.07800             0.07800   1.152             NaN
# 1                0.00500             0.00500     NaN             NaN
# 2                    NaN                 NaN     NaN             NaN
# 3                1.53491             1.53491     NaN             NaN
# 4                1.10000             1.10000     NaN             NaN
# ...                  ...                 ...     ...             ...
# 7409                 NaN                 NaN   0.292             NaN
# 7410                 NaN                 NaN   0.980            0.02
# 7411                 NaN                 NaN   0.680            0.07
# 7412                 NaN                 NaN   1.020            0.02
# 7413                 NaN                 NaN   0.490            0.04
#
#       radius_err_max  ...  star_dist_err_max  star_mass  star_mass_err_min  \
# 0                NaN  ...            0.88000       1.13              0.030
# 1                NaN  ...            0.10695       1.10              0.133
# 2                NaN  ...            0.10695       1.10              0.133
# 3                NaN  ...           10.50000       2.70              0.300
# 4                NaN  ...            6.90000       1.80              0.250
# ...              ...  ...                ...        ...                ...
# 7409             NaN  ...          200.00000       1.40                NaN
# 7410            0.02  ...                NaN       0.47                NaN
# 7411            0.07  ...            8.00000       0.90              0.050
# 7412            0.02  ...            5.00000       0.61              0.040
# 7413            0.04  ...           93.00000       0.76              0.050
#
#       star_mass_err_max  star_radius  star_radius_err_min  \
# 0                 0.030      1.79000               0.1700
# 1                 0.133      1.80100               0.0725
# 2                 0.133      1.80100               0.0725
# 3                 0.300     19.00000               2.0000
# 4                 0.250     24.08000               1.8400
# ...                 ...          ...                  ...
# 7409                NaN      0.00002                  NaN
# 7410                NaN      0.18200               0.0040
# 7411              0.050      0.00900               0.0010
# 7412              0.040      0.01310               0.0002
# 7413              0.050      0.01000               0.0010
#
#       star_radius_err_max           n     n_err_min     n_err_max
# 0                  0.1700    0.005843  8.975979e+00  8.975979e+00
# 1                  0.0725    1.427997  1.570796e+04  1.570796e+04
# 2                  0.0725    0.000173  1.040366e-03  1.040366e-03
# 3                  2.0000    0.019272  1.963495e+01  1.963495e+01
# 4                  1.8400    0.012172  1.933288e+00  1.933288e+00
# ...                   ...         ...           ...           ...
# 7409                  NaN  116.233408           NaN           NaN
# 7410               0.0040   90.031428           NaN           NaN
# 7411               0.0010  146.120589           NaN           NaN
# 7412               0.0002   56.096513  7.222052e+06  7.222052e+06
# 7413               0.0010  261.799388           NaN           NaN

# %% [markdown]
# If necessary, you can also save the dataset into memory, to avoid reading the source file again

# %%
datasets.load_eu(store=True)
# Out:
#  Loading the entire dataset...
#   Reading exoplanet_eu.csv directly from datasets.zip...
#  Updated stored index in memory.
#  Stored dataset in memory.
# Full ResokitDataset - 7414 rows x 45 columns
# Source: eu
# Age: 12 days
# Origin: zip
#                    name     mass  mass_err_min  mass_err_max  mass_sin_i  \
# 0             109 Psc b   5.7430       0.28900       0.28900      6.3830
# 1             112 Psc b   0.0330       0.00500       0.00500      0.0330
# 2             112 Psc c   9.8660       1.78100       1.78100         NaN
# 3             11 Com Ab  16.1284       1.53491       1.53491     16.1284
# 4              11 UMi b  11.0873       1.10000       1.10000     11.0873
# ...                 ...      ...           ...           ...         ...
# 7409  ZTF J1406+1222 Ab  50.0000           NaN           NaN         NaN
# 7410     ZTF J1622+47 b  61.0000      19.00000      19.00000         NaN
# 7411     ZTF J1637+49 b  23.0000       8.00000       8.00000         NaN
# 7412   ZTF J1828+2308 b  19.5000       0.80000       0.80000         NaN
# 7413     ZTF J2252-05 b  26.0000       8.00000       8.00000         NaN
#
#       mass_sin_i_err_min  mass_sin_i_err_max  radius  radius_err_min  \
# 0                0.07800             0.07800   1.152             NaN
# 1                0.00500             0.00500     NaN             NaN
# 2                    NaN                 NaN     NaN             NaN
# 3                1.53491             1.53491     NaN             NaN
# 4                1.10000             1.10000     NaN             NaN
# ...                  ...                 ...     ...             ...
# 7409                 NaN                 NaN   0.292             NaN
# 7410                 NaN                 NaN   0.980            0.02
# 7411                 NaN                 NaN   0.680            0.07
# 7412                 NaN                 NaN   1.020            0.02
# 7413                 NaN                 NaN   0.490            0.04
#
#       radius_err_max  ...  star_dist_err_max  star_mass  star_mass_err_min  \
# 0                NaN  ...            0.88000       1.13              0.030
# 1                NaN  ...            0.10695       1.10              0.133
# 2                NaN  ...            0.10695       1.10              0.133
# 3                NaN  ...           10.50000       2.70              0.300
# 4                NaN  ...            6.90000       1.80              0.250
# ...              ...  ...                ...        ...                ...
# 7409             NaN  ...          200.00000       1.40                NaN
# 7410            0.02  ...                NaN       0.47                NaN
# 7411            0.07  ...            8.00000       0.90              0.050
# 7412            0.02  ...            5.00000       0.61              0.040
# 7413            0.04  ...           93.00000       0.76              0.050
#
#       star_mass_err_max  star_radius  star_radius_err_min  \
# 0                 0.030      1.79000               0.1700
# 1                 0.133      1.80100               0.0725
# 2                 0.133      1.80100               0.0725
# 3                 0.300     19.00000               2.0000
# 4                 0.250     24.08000               1.8400
# ...                 ...          ...                  ...
# 7409                NaN      0.00002                  NaN
# 7410                NaN      0.18200               0.0040
# 7411              0.050      0.00900               0.0010
# 7412              0.040      0.01310               0.0002
# 7413              0.050      0.01000               0.0010
#
#       star_radius_err_max           n     n_err_min     n_err_max
# 0                  0.1700    0.005843  8.975979e+00  8.975979e+00
# 1                  0.0725    1.427997  1.570796e+04  1.570796e+04
# 2                  0.0725    0.000173  1.040366e-03  1.040366e-03
# 3                  2.0000    0.019272  1.963495e+01  1.963495e+01
# 4                  1.8400    0.012172  1.933288e+00  1.933288e+00
# ...                   ...         ...           ...           ...
# 7409                  NaN  116.233408           NaN           NaN
# 7410               0.0040   90.031428           NaN           NaN
# 7411               0.0010  146.120589           NaN           NaN
# 7412               0.0002   56.096513  7.222052e+06  7.222052e+06
# 7413               0.0010  261.799388           NaN           NaN

# %% [markdown]
# Now, the dataset will be loaded from memory, instead of reading the file again.

# %%
eu = datasets.load_eu()
eu
# Out:
#  Loaded full dataset from memory stored datasets.
# Full ResokitDataset - 7414 rows x 45 columns
# Source: eu
# Age: 12 days
# Origin: zip
#                    name     mass  mass_err_min  mass_err_max  mass_sin_i  \
# 0             109 Psc b   5.7430       0.28900       0.28900      6.3830
# 1             112 Psc b   0.0330       0.00500       0.00500      0.0330
# 2             112 Psc c   9.8660       1.78100       1.78100         NaN
# 3             11 Com Ab  16.1284       1.53491       1.53491     16.1284
# 4              11 UMi b  11.0873       1.10000       1.10000     11.0873
# ...                 ...      ...           ...           ...         ...
# 7409  ZTF J1406+1222 Ab  50.0000           NaN           NaN         NaN
# 7410     ZTF J1622+47 b  61.0000      19.00000      19.00000         NaN
# 7411     ZTF J1637+49 b  23.0000       8.00000       8.00000         NaN
# 7412   ZTF J1828+2308 b  19.5000       0.80000       0.80000         NaN
# 7413     ZTF J2252-05 b  26.0000       8.00000       8.00000         NaN
#
#       mass_sin_i_err_min  mass_sin_i_err_max  radius  radius_err_min  \
# 0                0.07800             0.07800   1.152             NaN
# 1                0.00500             0.00500     NaN             NaN
# 2                    NaN                 NaN     NaN             NaN
# 3                1.53491             1.53491     NaN             NaN
# 4                1.10000             1.10000     NaN             NaN
# ...                  ...                 ...     ...             ...
# 7409                 NaN                 NaN   0.292             NaN
# 7410                 NaN                 NaN   0.980            0.02
# 7411                 NaN                 NaN   0.680            0.07
# 7412                 NaN                 NaN   1.020            0.02
# 7413                 NaN                 NaN   0.490            0.04
#
#       radius_err_max  ...  star_dist_err_max  star_mass  star_mass_err_min  \
# 0                NaN  ...            0.88000       1.13              0.030
# 1                NaN  ...            0.10695       1.10              0.133
# 2                NaN  ...            0.10695       1.10              0.133
# 3                NaN  ...           10.50000       2.70              0.300
# 4                NaN  ...            6.90000       1.80              0.250
# ...              ...  ...                ...        ...                ...
# 7409             NaN  ...          200.00000       1.40                NaN
# 7410            0.02  ...                NaN       0.47                NaN
# 7411            0.07  ...            8.00000       0.90              0.050
# 7412            0.02  ...            5.00000       0.61              0.040
# 7413            0.04  ...           93.00000       0.76              0.050
#
#       star_mass_err_max  star_radius  star_radius_err_min  \
# 0                 0.030      1.79000               0.1700
# 1                 0.133      1.80100               0.0725
# 2                 0.133      1.80100               0.0725
# 3                 0.300     19.00000               2.0000
# 4                 0.250     24.08000               1.8400
# ...                 ...          ...                  ...
# 7409                NaN      0.00002                  NaN
# 7410                NaN      0.18200               0.0040
# 7411              0.050      0.00900               0.0010
# 7412              0.040      0.01310               0.0002
# 7413              0.050      0.01000               0.0010
#
#       star_radius_err_max           n     n_err_min     n_err_max
# 0                  0.1700    0.005843  8.975979e+00  8.975979e+00
# 1                  0.0725    1.427997  1.570796e+04  1.570796e+04
# 2                  0.0725    0.000173  1.040366e-03  1.040366e-03
# 3                  2.0000    0.019272  1.963495e+01  1.963495e+01
# 4                  1.8400    0.012172  1.933288e+00  1.933288e+00
# ...                   ...         ...           ...           ...
# 7409                  NaN  116.233408           NaN           NaN
# 7410               0.0040   90.031428           NaN           NaN
# 7411               0.0010  146.120589           NaN           NaN
# 7412               0.0002   56.096513  7.222052e+06  7.222052e+06
# 7413               0.0010  261.799388           NaN           NaN

# %%
# Load NASA dataset too
nasa_full = datasets.load_nasa(store=True, check_age=True)

# Nasa dataset contains all exoplanet solutions (including non default and controversial), so we filter them here
nasa = nasa_full[(nasa_full.controversial == 0) & (nasa_full.default_set == 1)]
nasa
# Out:
#  Loading the entire dataset...
#   Reading nasa.csv directly from datasets.zip...
#  Last modified: 2025-02-14 06:10:26 (12 days ago).
#  Updated stored index in memory.
#  Stored dataset in memory.
# Partial ResokitDataset - 5801 rows x 49 columns
# Source: nasa
# Age: 12 days
# Origin: zip
#                 name    star_name  default_set  \
# 0       OGLE-TR-10 b   OGLE-TR-10            1
# 2       BD-08 2823 c   BD-08 2823            1
# 24       HD 110014 b    HD 110014            1
# 33        GJ 667 C c     GJ 667 C            1
# 35      Kepler-227 b   Kepler-227            1
# ...              ...          ...          ...
# 38074  Kepler-1295 b  Kepler-1295            1
# 38086  Kepler-1685 b  Kepler-1685            1
# 38087  Kepler-1138 b  Kepler-1138            1
# 38088   Kepler-586 b   Kepler-586            1
# 38089   Kepler-592 b   Kepler-592            1
#
#                                                reference  disc_year  \
# 0      <a refstr=TORRES_ET_AL__2008 href=https://ui.a...       2004
# 2      <a refstr=HEBRARD_ET_AL__2010 href=https://ui....       2009
# 24     <a refstr=DE_MEDEIROS_ET_AL__2009 href=https:/...       2009
# 33     <a refstr=ANGLADA_ESCUDE_ET_AL__2013 href=http...       2013
# 35     <a refstr=ROWE_ET_AL__2014 href=https://ui.ads...       2014
# ...                                                  ...        ...
# 38074  <a refstr=MORTON_ET_AL__2016 href=https://ui.a...       2016
# 38086  <a refstr=ARMSTRONG_ET_AL__2021 href=https://u...       2020
# 38087  <a refstr=MORTON_ET_AL__2016 href=https://ui.a...       2016
# 38088  <a refstr=MORTON_ET_AL__2016 href=https://ui.a...       2016
# 38089  <a refstr=MORTON_ET_AL__2016 href=https://ui.a...       2016
#
#            disc_method           P     P_err_min     P_err_max  w_err_min  \
# 0              Transit    3.101278           NaN           NaN        NaN
# 2      Radial Velocity  237.600000  1.500000e+00  1.500000e+00       21.0
# 24     Radial Velocity  835.477000  6.040000e+00  6.040000e+00        3.8
# 33     Radial Velocity   28.140000  5.300000e-02  6.500000e-02       67.8
# 35             Transit    9.488015  3.900000e-05  3.900000e-05        NaN
# ...                ...         ...           ...           ...        ...
# 38074          Transit    3.813720  2.278000e-05  2.278000e-05        NaN
# 38086          Transit   20.490500           NaN           NaN        NaN
# 38087          Transit    3.170600  1.019000e-05  1.019000e-05        NaN
# 38088          Transit    2.104722  9.200000e-07  9.200000e-07        NaN
# 38089          Transit    2.820192  3.790000e-06  3.790000e-06        NaN
#
#        ...  star_radius_err_min  star_radius_err_max  n_stars  n_planets  \
# 0      ...                 0.13                  NaN        1          1
# 2      ...                  NaN                  NaN        1          2
# 24     ...                 1.10                 1.10        1          1
# 33     ...                  NaN                  NaN        3          5
# 35     ...                 0.55                 0.55        1          2
# ...    ...                  ...                  ...      ...        ...
# 38074  ...                 0.10                 0.06        1          1
# 38086  ...                  NaN                  NaN        1          1
# 38087  ...                 0.13                 0.06        1          1
# 38088  ...                 0.12                 0.07        1          1
# 38089  ...                 0.25                 0.10        1          1
#
#         star_dist  star_dist_err_min  star_dist_err_max         n  \
# 0      1344.97000          111.66500          111.66500  2.025999
# 2        41.33420            0.06850            0.06820  0.026444
# 24      100.75800            1.97315            1.97315  0.007520
# 33        7.24396            0.00486            0.00485  0.223283
# 35     1083.06000           29.67000           29.67000  0.662223
# ...           ...                ...                ...       ...
# 38074  1174.46000           57.58000           52.53000  1.647522
# 38086  1141.89000           44.55000           41.37000  0.306639
# 38087   872.32800           22.71700           21.61200  1.981702
# 38088   693.76600           10.39350           10.39350  2.985280
# 38089  1153.13000           25.44000           24.38000  2.227928
#
#           n_err_min     n_err_max
# 0               NaN           NaN
# 2      4.188790e+00  4.188790e+00
# 24     1.040262e+00  1.040262e+00
# 33     9.666439e+01  1.185507e+02
# 35     1.611073e+05  1.611073e+05
# ...             ...           ...
# 38074  2.758203e+05  2.758203e+05
# 38086           NaN           NaN
# 38087  6.166031e+05  6.166031e+05
# 38088  6.829549e+06  6.829549e+06
# 38089  1.657833e+06  1.657833e+06

# %% [markdown]
# We can see both datasets have different amount of exoplanets:

# %%
print(f"# of planets in NASA dataset: {nasa.shape[0]}")
print(f"# of planets in EU dataset: {eu.shape[0]}")
# Out:
# # of planets in NASA dataset: 5801
# # of planets in EU dataset: 7414

# %% [markdown]
# Checking the columns, we find that both data frames have almost all equal column names

# %%
print(f"{'Column':^19s} || {'NASA':^4s} | {'EU':^4s}")
print("-" * 50)
for col in nasa.columns.sort_values():
    print(f"{col:>19s} || {'YES':^4s} | {'YES' if col in eu.columns else 'NO':^4s}")
# Out:
#       Column        || NASA |  EU
# --------------------------------------------------
#                   P || YES  | YES
#           P_err_max || YES  | YES
#           P_err_min || YES  | YES
#                   a || YES  | YES
#           a_err_max || YES  | YES
#           a_err_min || YES  | YES
#       controversial || YES  |  NO
#         default_set || YES  |  NO
#         disc_method || YES  | YES
#           disc_year || YES  | YES
#                   e || YES  | YES
#           e_err_max || YES  | YES
#           e_err_min || YES  | YES
#                 inc || YES  | YES
#         inc_err_max || YES  | YES
#         inc_err_min || YES  | YES
#                mass || YES  | YES
#        mass_err_max || YES  | YES
#        mass_err_min || YES  | YES
#          mass_sin_i || YES  | YES
#  mass_sin_i_err_max || YES  | YES
#  mass_sin_i_err_min || YES  | YES
#                   n || YES  | YES
#           n_err_max || YES  | YES
#           n_err_min || YES  | YES
#           n_planets || YES  |  NO
#             n_stars || YES  |  NO
#                name || YES  | YES
#              radius || YES  | YES
#      radius_err_max || YES  | YES
#      radius_err_min || YES  | YES
#           reference || YES  | YES
#           rowupdate || YES  | YES
#           star_dist || YES  | YES
#   star_dist_err_max || YES  | YES
#   star_dist_err_min || YES  | YES
#           star_mass || YES  | YES
#   star_mass_err_max || YES  | YES
#   star_mass_err_min || YES  | YES
#           star_name || YES  | YES
#         star_radius || YES  | YES
# star_radius_err_max || YES  | YES
# star_radius_err_min || YES  | YES
#               tperi || YES  | YES
#       tperi_err_max || YES  | YES
#       tperi_err_min || YES  | YES
#                   w || YES  | YES
#           w_err_max || YES  | YES
#           w_err_min || YES  | YES

# %% [markdown]
# The only differences are:
# - controversial : The exoplanet is confirmed (0) or not yet (1).
# - default_set : The solution is the default set (1) or not (0).
# - n_planets : Amount of planets in that system.
# - n_stars : Amount of stars in that system.

# %% [markdown]
# We can see both datasets are similar, but not equal.

# %%
plt.figure(figsize=(5,4), dpi=130)
plt.plot(eu.mass, eu.radius, ".", ms=10, label="EU")
plt.plot(nasa.mass, nasa.radius, "x", ms=3, label="NASA")
plt.semilogx()
plt.semilogy()
plt.xlabel("Planet mass [M$_\\mathrm{J}$]")
plt.ylabel("Planet radius [R$_\\mathrm{J}$]")
plt.suptitle("Mass vs Radius comparison")
plt.xlim(1e-4, 1e2)
plt.ylim(bottom=1e-2)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5,4), dpi=130)
plt.plot(eu.a, eu.e, ".", ms=10, label="EU")
plt.plot(nasa.a, nasa.e, "x", ms=3, label="NASA")
plt.semilogx()
plt.semilogy()
plt.xlabel("Planet semimajor-axis [AU]")
plt.ylabel("Planet eccentricity")
plt.suptitle("$a$ vs $e$ comparison")
plt.ylim(bottom=1e-5)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Load full dataset
#
# Some planet and star data are not shown because the full data has been trimmed, when using `to_resokit=True` in `load` function.
#
# All data can be obtained using `to_resokit=False`. Moreover, if we wanted a `pandas Dataframe`, also use `to_df=True`. Nevertheless, in this case the column names will be the original from each database, instead of being mapped into more comprehensive ones.

# %%
nasa_original = datasets.load_nasa(to_resokit=False)
nasa_original
# Out:
#  Loaded full dataset from memory stored datasets.
# Full ResokitDataset - 38090 rows x 354 columns
# Source: nasa
# Age: 12 days
# Origin: zip
#              pl_name pl_letter     hostname    hd_name   hip_name  \
# 0       OGLE-TR-10 b         b   OGLE-TR-10        NaN        NaN
# 1       BD-08 2823 b         b   BD-08 2823        NaN  HIP 49067
# 2       BD-08 2823 c         c   BD-08 2823        NaN  HIP 49067
# 3        HD 104985 b         b    HD 104985  HD 104985  HIP 58952
# 4          bet Pic b         b      bet Pic   HD 39060  HIP 27321
# ...              ...       ...          ...        ...        ...
# 38085   Kepler-729 b         b   Kepler-729        NaN        NaN
# 38086  Kepler-1685 b         b  Kepler-1685        NaN        NaN
# 38087  Kepler-1138 b         b  Kepler-1138        NaN        NaN
# 38088   Kepler-586 b         b   Kepler-586        NaN        NaN
# 38089   Kepler-592 b         b   Kepler-592        NaN        NaN
#
#               tic_id                       gaia_id  default_flag  \
# 0      TIC 130150682  Gaia DR2 4056443366649948160             1
# 1       TIC 33355302  Gaia DR2 3770419611540574080             0
# 2       TIC 33355302  Gaia DR2 3770419611540574080             1
# 3      TIC 160224839  Gaia DR2 1693159194226600192             0
# 4      TIC 270577175  Gaia DR2 4792774797545105664             0
# ...              ...                           ...           ...
# 38085  TIC 158269049  Gaia DR2 2106432870280171136             0
# 38086  TIC 272270869  Gaia DR2 2079576783379820928             1
# 38087  TIC 405685914  Gaia DR2 2131896494426821760             1
# 38088  TIC 275490218  Gaia DR2 2126537234238972544             1
# 38089  TIC 377782184  Gaia DR2 2131920370147385472             1
#
#                                               pl_refname  \
# 0      <a refstr=TORRES_ET_AL__2008 href=https://ui.a...
# 1      <a refstr=HEBRARD_ET_AL__2010 href=https://ui....
# 2      <a refstr=HEBRARD_ET_AL__2010 href=https://ui....
# 3      <a refstr=SATO_ET_AL__2003 href=https://ui.ads...
# 4      <a refstr=MACINTOSH_ET_AL__2014 href=https://u...
# ...                                                  ...
# 38085  <a refstr=Q1_Q16_KOI_TABLE href=https://exopla...
# 38086  <a refstr=ARMSTRONG_ET_AL__2021 href=https://u...
# 38087  <a refstr=MORTON_ET_AL__2016 href=https://ui.a...
# 38088  <a refstr=MORTON_ET_AL__2016 href=https://ui.a...
# 38089  <a refstr=MORTON_ET_AL__2016 href=https://ui.a...
#
#                                               sy_refname  ... sy_jmagerr1  \
# 0      <a refstr=STASSUN_ET_AL__2019 href=https://ui....  ...         NaN
# 1      <a refstr=STASSUN_ET_AL__2019 href=https://ui....  ...       0.020
# 2      <a refstr=STASSUN_ET_AL__2019 href=https://ui....  ...       0.020
# 3      <a refstr=STASSUN_ET_AL__2019 href=https://ui....  ...       0.226
# 4      <a refstr=STASSUN_ET_AL__2019 href=https://ui....  ...       0.236
# ...                                                  ...  ...         ...
# 38085  <a refstr=STASSUN_ET_AL__2019 href=https://ui....  ...       0.032
# 38086  <a refstr=STASSUN_ET_AL__2019 href=https://ui....  ...       0.034
# 38087  <a refstr=STASSUN_ET_AL__2019 href=https://ui....  ...       0.030
# 38088  <a refstr=STASSUN_ET_AL__2019 href=https://ui....  ...       0.024
# 38089  <a refstr=STASSUN_ET_AL__2019 href=https://ui....  ...       0.027
#
#        sy_jmagerr2           sy_jmagstr sy_hmag sy_hmagerr1 sy_hmagerr2  \
# 0              NaN               13.692  13.314       0.121      -0.121
# 1           -0.020     7.96&plusmn;0.02   7.498       0.047      -0.047
# 2           -0.020     7.96&plusmn;0.02   7.498       0.047      -0.047
# 3           -0.226   4.112&plusmn;0.226   3.547       0.194      -0.194
# 4           -0.236   3.669&plusmn;0.236   3.544       0.200      -0.200
# ...            ...                  ...     ...         ...         ...
# 38085       -0.032  14.471&plusmn;0.032  14.028       0.040      -0.040
# 38086       -0.034  14.598&plusmn;0.034  14.185       0.040      -0.040
# 38087       -0.030  14.135&plusmn;0.030  13.775       0.046      -0.046
# 38088       -0.024  13.247&plusmn;0.024  12.865       0.024      -0.024
# 38089       -0.027  13.626&plusmn;0.027  13.300       0.034      -0.034
#
#                 sy_hmagstr sy_kmag  sy_kmagerr1 sy_kmagerr2
# 0      13.314&plusmn;0.121  12.856          NaN         NaN
# 1       7.498&plusmn;0.047   7.323        0.021      -0.021
# 2       7.498&plusmn;0.047   7.323        0.021      -0.021
# 3       3.547&plusmn;0.194   3.274        0.304      -0.304
# 4       3.544&plusmn;0.200   3.526        0.222      -0.222
# ...                    ...     ...          ...         ...
# 38085  14.028&plusmn;0.040  14.086        0.060      -0.060
# 38086  14.185&plusmn;0.040  14.059        0.062      -0.062
# 38087  13.775&plusmn;0.046  13.754        0.045      -0.045
# 38088  12.865&plusmn;0.024  12.742        0.036      -0.036
# 38089  13.300&plusmn;0.034  13.219        0.039      -0.039

# %% [markdown]
# We see that the amount of columns is larger than before

# %%
print("# of columns in nasa (to_resokit=True):", nasa.shape[1])
print("# of columns in nasa (to_resokit=False):", nasa_original.shape[1])
# Out:
# # of columns in nasa (to_resokit=True): 49
# # of columns in nasa (to_resokit=False): 354

# %% [markdown]
# Also, we can see that **mass** or **radius** are not in the dataframe, but it has **pl_massj** and **pl_radj** instead.

# %%
print("'mass' in nasa_original:", "mass" in nasa_original.columns)
print("'radius' in nasa_original:", "radius" in nasa_original.columns)

print("'pl_massj' in nasa_original:", "pl_massj" in nasa_original.columns)
print("'pl_radj' in nasa_original:", "pl_radj" in nasa_original.columns)
# Out:
# 'mass' in nasa_original: False
# 'radius' in nasa_original: False
# 'pl_massj' in nasa_original: True
# 'pl_radj' in nasa_original: True

# %% [markdown]
# ## Default units
#
# More information about the units can be found at:
# - EU: [https://exoplanet.eu/readme/](https://exoplanet.eu/readme/)
# - NASA: [https://exoplanetarchive.ipac.caltech.edu/docs/API_PS_columns.html](https://exoplanetarchive.ipac.caltech.edu/docs/API_PS_columns.html)
#
# but the basics are:
#
# - Planet:
#     - mass: Jupiter masses
#     - radius: Jupiter radii
#     - semimajor-axes: au
#
# - Star:
#     - mass: Solar masses
#     - radius: Solar radii
#     - distance: Parsecs

# %% [markdown]
# ## Update
#
#
# When loading a dataset, we can set `check_age=True` to get info about when the dataset was updated on our local machine.

# %%
datasets.load_eu(check_age=True)
# Out:
#  Loaded full dataset from memory stored datasets.
#  Last modified: 12 days ago.
# Full ResokitDataset - 7414 rows x 45 columns
# Source: eu
# Age: 12 days
# Origin: zip
#                    name     mass  mass_err_min  mass_err_max  mass_sin_i  \
# 0             109 Psc b   5.7430       0.28900       0.28900      6.3830
# 1             112 Psc b   0.0330       0.00500       0.00500      0.0330
# 2             112 Psc c   9.8660       1.78100       1.78100         NaN
# 3             11 Com Ab  16.1284       1.53491       1.53491     16.1284
# 4              11 UMi b  11.0873       1.10000       1.10000     11.0873
# ...                 ...      ...           ...           ...         ...
# 7409  ZTF J1406+1222 Ab  50.0000           NaN           NaN         NaN
# 7410     ZTF J1622+47 b  61.0000      19.00000      19.00000         NaN
# 7411     ZTF J1637+49 b  23.0000       8.00000       8.00000         NaN
# 7412   ZTF J1828+2308 b  19.5000       0.80000       0.80000         NaN
# 7413     ZTF J2252-05 b  26.0000       8.00000       8.00000         NaN
#
#       mass_sin_i_err_min  mass_sin_i_err_max  radius  radius_err_min  \
# 0                0.07800             0.07800   1.152             NaN
# 1                0.00500             0.00500     NaN             NaN
# 2                    NaN                 NaN     NaN             NaN
# 3                1.53491             1.53491     NaN             NaN
# 4                1.10000             1.10000     NaN             NaN
# ...                  ...                 ...     ...             ...
# 7409                 NaN                 NaN   0.292             NaN
# 7410                 NaN                 NaN   0.980            0.02
# 7411                 NaN                 NaN   0.680            0.07
# 7412                 NaN                 NaN   1.020            0.02
# 7413                 NaN                 NaN   0.490            0.04
#
#       radius_err_max  ...  star_dist_err_max  star_mass  star_mass_err_min  \
# 0                NaN  ...            0.88000       1.13              0.030
# 1                NaN  ...            0.10695       1.10              0.133
# 2                NaN  ...            0.10695       1.10              0.133
# 3                NaN  ...           10.50000       2.70              0.300
# 4                NaN  ...            6.90000       1.80              0.250
# ...              ...  ...                ...        ...                ...
# 7409             NaN  ...          200.00000       1.40                NaN
# 7410            0.02  ...                NaN       0.47                NaN
# 7411            0.07  ...            8.00000       0.90              0.050
# 7412            0.02  ...            5.00000       0.61              0.040
# 7413            0.04  ...           93.00000       0.76              0.050
#
#       star_mass_err_max  star_radius  star_radius_err_min  \
# 0                 0.030      1.79000               0.1700
# 1                 0.133      1.80100               0.0725
# 2                 0.133      1.80100               0.0725
# 3                 0.300     19.00000               2.0000
# 4                 0.250     24.08000               1.8400
# ...                 ...          ...                  ...
# 7409                NaN      0.00002                  NaN
# 7410                NaN      0.18200               0.0040
# 7411              0.050      0.00900               0.0010
# 7412              0.040      0.01310               0.0002
# 7413              0.050      0.01000               0.0010
#
#       star_radius_err_max           n     n_err_min     n_err_max
# 0                  0.1700    0.005843  8.975979e+00  8.975979e+00
# 1                  0.0725    1.427997  1.570796e+04  1.570796e+04
# 2                  0.0725    0.000173  1.040366e-03  1.040366e-03
# 3                  2.0000    0.019272  1.963495e+01  1.963495e+01
# 4                  1.8400    0.012172  1.933288e+00  1.933288e+00
# ...                   ...         ...           ...           ...
# 7409                  NaN  116.233408           NaN           NaN
# 7410               0.0040   90.031428           NaN           NaN
# 7411               0.0010  146.120589           NaN           NaN
# 7412               0.0002   56.096513  7.222052e+06  7.222052e+06
# 7413               0.0010  261.799388           NaN           NaN

# %% [markdown]
# We can query the online dataset length to compare with our local database. To do so, we call
# `check_online_dataset`

# %%
datasets.check_online_dataset("eu")
# Out:
# Checking online dataset from eu...
#  Last online update: 2025-02-26 (1 days ago)
#  Number of planets in online dataset: 7416
# (7416, datetime.datetime(2025, 2, 26, 0, 0))

# %% [markdown]
# To compare with local, simply run `check_outdated`

# %%
datasets.check_outdated("eu")
# Out:
# Checking local dataset from eu...
#  Last modified: 12 days ago.
#  Number of planets in stored dataset: 7414
# Checking online dataset from eu...
#  Last online update: 2025-02-26 (1 days ago)
#  Number of planets in online dataset: 7416
# The dataset is outdated.
# True

# %% [markdown]
# To perform a dataset update, we can use the function `update_eu` or `update_nasa`; or the main function `download`.

# %%
datasets.download?
# Out:
# Signature:
# datasets.download(
#     source: str,
#     to_memory: bool = True,
#     to_file: Union[str, pathlib.Path, bool, NoneType] = False,
#     to_zip: Union[str, pathlib.Path, bool, NoneType] = False,
#     dir_path: Union[str, pathlib.Path, NoneType] = None,
#     overwrite: bool = False,
#     check_online: bool = True,
#     to_resokit: Optional[bool] = None,
#     verbose: bool = True,
#     chunk_size: int = 1024,
#     print_size: float = 0.15,
# ) -> Union[pathlib.Path, pandas.core.frame.DataFrame, resokit.datasets.databases.ResoKitDataset]
# Docstring:
# Download a dataset from a specified source and save it locally.
#
# The dataset is downloaded from the internet, from the online NASA
# or exoplanet.eu databases, and can be stored in a file, a ZIP archive,
# in memory, and/or simply returned.
#
# Note
# ----
# Requires the requests library.
#
# Parameters
# ----------
# source : str
#     Identifier for the data source ('eu' or 'nasa').
# to_memory : bool, optional. Default: False.
#     If `True`, stores the dataset in memory.
# to_file : str or Path or bool, optional. Default: False.
#     Path or str to the file to store the dataset.
#     If `True`, default filename is used.
#     If `False`, the file is not saved nor created.
# to_zip : str or Path or bool, optional. Default: False.
#     Path or str to the ZIP archive to store the dataset.
#     If `True`, default ZIP filename is used. (datasets.zip)
#     If `False`, the file is not saved nor created in the ZIP archive.
# dir_path : str or Path
#     Directory path to save the dataset, or path to the ZIP archive.
#     If `None`, the default directory is used (resokit.datasets).
# overwrite : bool, optional. Default: False.
#     If `True`, overwrites the file if it already exists.
#     The memory stored Dataset and Index are always overwritten,
#     independently of this parameter.
# check_online : bool, optional. Default: True.
#     Whether to check if the dataset is already up-to-date.
# to_resokit : bool, dict, optional. Default: None.
#     If `True`, returns the dataset as a ResoKitDataset.
#     If `False`, returns the dataset as a pandas DataFrame.
#     If `None`, returns the path to the downloaded file.
# verbose : bool, optional. Default: True.
#     If `True`, displays messages about the download process.
# chunk_size : int, optional. Default: 1024.
#     Size of the chunks to download the dataset, in bytes.
#     Default is 1024 bytes (1 KB).
# print_size: float, optional. Default: 0.15.
#     Update frequency for the download progress bar.
#
# Returns
# -------
# downloaded : Path or pd.DataFrame or None
#     `Path` to the downloaded dataset (and or zip archive),
#     or the dataset if `to_resokit` is not `None`.
# File:      ~/Documentos/git/ResoKit/resokit/datasets/databases.py
# Type:      function

# %% [markdown]
# To download an update EU database, and store it as a .csv we simply run

# %%
data = datasets.download("eu", to_file="/tmp/new_eu.csv", to_resokit=True)
data
# Out:
# Checking local dataset from eu...
#  Last modified: 12 days ago.
#  Number of planets in stored dataset: 7414
# Checking online dataset from eu...
#  Last online update: 2025-02-26 (1 days ago)
#  Number of planets in online dataset: 7416
# The dataset is outdated.
# Downloading data from https://exoplanet.eu/catalog/csv/...
#  Note: Progress is shown at every 0.15 MB
#  Data downloaded successfully. (3.30 MB)
#  Creating the file /tmp/new_eu.csv...
#  Written /tmp/new_eu.csv.
#  Updated stored index in memory.
#  Stored dataset in memory.
# Full ResokitDataset - 7416 rows x 45 columns
# Source: eu
# Age: 0 days
# Origin: internet
#                    name    mass  mass_err_min  mass_err_max  mass_sin_i  \
# 0             109 Psc b   5.743       0.28900       1.01100      6.3830
# 1             112 Psc b     NaN       0.00500       0.00400      0.0330
# 2             112 Psc c   9.866       1.78100       3.19000         NaN
# 3             11 Com Ab     NaN       1.53491       1.53491     16.1284
# 4              11 UMi b     NaN       1.10000       1.10000     11.0873
# ...                 ...     ...           ...           ...         ...
# 7411  ZTF J1406+1222 Ab  50.000           NaN           NaN         NaN
# 7412     ZTF J1622+47 b  61.000      19.00000      19.00000         NaN
# 7413     ZTF J1637+49 b  23.000       8.00000       8.00000         NaN
# 7414   ZTF J1828+2308 b  19.500       0.80000       0.80000         NaN
# 7415     ZTF J2252-05 b  26.000       8.00000       8.00000         NaN
#
#       mass_sin_i_err_min  mass_sin_i_err_max  radius  radius_err_min  \
# 0                0.07800             0.07800   1.152             NaN
# 1                0.00500             0.00400     NaN             NaN
# 2                    NaN                 NaN     NaN             NaN
# 3                1.53491             1.53491     NaN             NaN
# 4                1.10000             1.10000     NaN             NaN
# ...                  ...                 ...     ...             ...
# 7411                 NaN                 NaN   0.292             NaN
# 7412                 NaN                 NaN   0.980            0.02
# 7413                 NaN                 NaN   0.680            0.07
# 7414                 NaN                 NaN   1.020            0.02
# 7415                 NaN                 NaN   0.490            0.04
#
#       radius_err_max  ...  star_dist_err_max  star_mass  star_mass_err_min  \
# 0                NaN  ...            0.88000       1.13              0.030
# 1                NaN  ...            0.10695       1.10              0.133
# 2                NaN  ...            0.10695       1.10              0.133
# 3                NaN  ...           10.50000       2.70              0.300
# 4                NaN  ...            6.90000       1.80              0.250
# ...              ...  ...                ...        ...                ...
# 7411             NaN  ...          200.00000       1.40                NaN
# 7412            0.02  ...                NaN       0.47                NaN
# 7413            0.07  ...            8.00000       0.90              0.050
# 7414            0.02  ...            5.00000       0.61              0.040
# 7415            0.04  ...           82.00000       0.76              0.050
#
#       star_mass_err_max  star_radius  star_radius_err_min  \
# 0                 0.030      1.79000               0.1700
# 1                 0.133      1.80100               0.0725
# 2                 0.133      1.80100               0.0725
# 3                 0.300     19.00000               2.0000
# 4                 0.250     24.08000               1.8400
# ...                 ...          ...                  ...
# 7411                NaN      0.00002                  NaN
# 7412                NaN      0.18200               0.0040
# 7413              0.050      0.00900               0.0010
# 7414              0.040      0.01310               0.0002
# 7415              0.050      0.01000               0.0010
#
#       star_radius_err_max           n     n_err_min     n_err_max
# 0                  0.1700    0.005843  7.853982e+00  8.975979e+00
# 1                  0.0725    1.427997  3.141593e+04  1.570796e+04
# 2                  0.0725    0.000173  6.460195e-04  1.040366e-03
# 3                  2.0000    0.019272  1.963495e+01  1.963495e+01
# 4                  1.8400    0.012172  1.933288e+00  1.933288e+00
# ...                   ...         ...           ...           ...
# 7411                  NaN  116.233408           NaN           NaN
# 7412               0.0040   90.031428           NaN           NaN
# 7413               0.0010  146.120589           NaN           NaN
# 7414               0.0002   56.096513  7.222052e+06  7.222052e+06
# 7415               0.0010  261.799388           NaN           NaN

# %% [markdown]
# To replace a file just use `overwrite=True`, even to replace the file inside datasets.zip (`to_zip=True`).
