# %% [markdown]
# # Resokit.datasets Tutorial
#
#
# This tutorial is a guide to use ResoKit.datasets package.
# ResoKit.datasets provides tools for loading the available datasets:
# - [NASA](https://exoplanetarchive.ipac.caltech.edu/)
# - [EU](https://exoplanet.eu/home/)
#
# In this tutorial we show, step by step, how to get started with the ResoKit.datasets package.
#
# ---

# %% [markdown]
# ## Import ResoKit and the necessary packages

# %%
import resokit.datasets as datasets

import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the dataset
#
# Let's start with EU catalogue.

# %%
data = datasets.load_eu()
data
# Out:
#  Loading the entire dataset...
#   Reading exoplanet_eu.csv directly from datasets.zip...
# Full ResokitDataset - 7407 rows x 45 columns
# Source: eu
# Age: 9 days
# Origin: zip
#                                 name     mass  mass_err_min  mass_err_max  \
# name
# 109 Psc b                  109 Psc b   5.7430       0.28900       0.28900
# 112 Psc b                  112 Psc b   0.0330       0.00500       0.00500
# 112 Psc c                  112 Psc c   9.8660       1.78100       1.78100
# 11 Com Ab                  11 Com Ab  16.1284       1.53491       1.53491
# 11 UMi b                    11 UMi b  11.0873       1.10000       1.10000
# ...                              ...      ...           ...           ...
# ZTF J0407-00 b        ZTF J0407-00 b  19.0000       3.00000       3.00000
# ZTF J1406+1222 Ab  ZTF J1406+1222 Ab  50.0000           NaN           NaN
# ZTF J1622+47 b        ZTF J1622+47 b  61.0000      19.00000      19.00000
# ZTF J1637+49 b        ZTF J1637+49 b  23.0000       8.00000       8.00000
# ZTF J2252-05 b        ZTF J2252-05 b  26.0000       8.00000       8.00000
#
#                    mass_sin_i  mass_sin_i_err_min  mass_sin_i_err_max  radius  \
# name
# 109 Psc b              6.3830             0.07800             0.07800   1.152
# 112 Psc b              0.0330             0.00500             0.00500     NaN
# 112 Psc c                 NaN                 NaN                 NaN     NaN
# 11 Com Ab             16.1284             1.53491             1.53491     NaN
# 11 UMi b              11.0873             1.10000             1.10000     NaN
# ...                       ...                 ...                 ...     ...
# ZTF J0407-00 b            NaN                 NaN                 NaN   0.440
# ZTF J1406+1222 Ab         NaN                 NaN                 NaN   0.292
# ZTF J1622+47 b            NaN                 NaN                 NaN   0.980
# ZTF J1637+49 b            NaN                 NaN                 NaN   0.680
# ZTF J2252-05 b            NaN                 NaN                 NaN   0.490
#
#                    radius_err_min  radius_err_max  ...  star_dist_err_max  \
# name                                               ...
# 109 Psc b                     NaN             NaN  ...            0.88000
# 112 Psc b                     NaN             NaN  ...            0.10695
# 112 Psc c                     NaN             NaN  ...            0.10695
# 11 Com Ab                     NaN             NaN  ...           10.50000
# 11 UMi b                      NaN             NaN  ...            6.90000
# ...                           ...             ...  ...                ...
# ZTF J0407-00 b               0.02            0.02  ...          230.00000
# ZTF J1406+1222 Ab             NaN             NaN  ...          200.00000
# ZTF J1622+47 b               0.02            0.02  ...                NaN
# ZTF J1637+49 b               0.07            0.07  ...            8.00000
# ZTF J2252-05 b               0.04            0.04  ...           93.00000
#
#                    star_mass  star_mass_err_min  star_mass_err_max  \
# name
# 109 Psc b               1.13              0.030              0.030
# 112 Psc b               1.10              0.133              0.133
# 112 Psc c               1.10              0.133              0.133
# 11 Com Ab               2.70              0.300              0.300
# 11 UMi b                1.80              0.250              0.250
# ...                      ...                ...                ...
# ZTF J0407-00 b          0.79              0.060              0.060
# ZTF J1406+1222 Ab       1.40                NaN                NaN
# ZTF J1622+47 b          0.47                NaN                NaN
# ZTF J1637+49 b          0.90              0.050              0.050
# ZTF J2252-05 b          0.76              0.050              0.050
#
#                    star_radius  star_radius_err_min  star_radius_err_max  \
# name
# 109 Psc b              1.79000               0.1700               0.1700
# 112 Psc b              1.80100               0.0725               0.0725
# 112 Psc c              1.80100               0.0725               0.0725
# 11 Com Ab             19.00000               2.0000               2.0000
# 11 UMi b              24.08000               1.8400               1.8400
# ...                        ...                  ...                  ...
# ZTF J0407-00 b         0.01000               0.0010               0.0010
# ZTF J1406+1222 Ab      0.00002                  NaN                  NaN
# ZTF J1622+47 b         0.18200               0.0040               0.0040
# ZTF J1637+49 b         0.00900               0.0010               0.0010
# ZTF J2252-05 b         0.01000               0.0010               0.0010
#
#                             n     n_err_min     n_err_max
# name
# 109 Psc b            0.005843      8.975979      8.975979
# 112 Psc b            1.427997  15707.963268  15707.963268
# 112 Psc c            0.000173      0.001040      0.001040
# 11 Com Ab            0.019272     19.634954     19.634954
# 11 UMi b             0.012172      1.933288      1.933288
# ...                       ...           ...           ...
# ZTF J0407-00 b     255.414037           NaN           NaN
# ZTF J1406+1222 Ab  116.233408           NaN           NaN
# ZTF J1622+47 b      90.031428           NaN           NaN
# ZTF J1637+49 b     146.120589           NaN           NaN
# ZTF J2252-05 b     261.799388           NaN           NaN

# %% [markdown]
# If necessary, you can also save the dataset into memory, to avoid reading the source file again

# %%
datasets.load_eu(store=True)
# Out:
#  Loading the entire dataset...
#   Reading exoplanet_eu.csv directly from datasets.zip...
#  Updated stored index in memory.
#  Stored dataset in memory.
# Full ResokitDataset - 7407 rows x 45 columns
# Source: eu
# Age: 9 days
# Origin: zip
#                                 name     mass  mass_err_min  mass_err_max  \
# name
# 109 Psc b                  109 Psc b   5.7430       0.28900       0.28900
# 112 Psc b                  112 Psc b   0.0330       0.00500       0.00500
# 112 Psc c                  112 Psc c   9.8660       1.78100       1.78100
# 11 Com Ab                  11 Com Ab  16.1284       1.53491       1.53491
# 11 UMi b                    11 UMi b  11.0873       1.10000       1.10000
# ...                              ...      ...           ...           ...
# ZTF J0407-00 b        ZTF J0407-00 b  19.0000       3.00000       3.00000
# ZTF J1406+1222 Ab  ZTF J1406+1222 Ab  50.0000           NaN           NaN
# ZTF J1622+47 b        ZTF J1622+47 b  61.0000      19.00000      19.00000
# ZTF J1637+49 b        ZTF J1637+49 b  23.0000       8.00000       8.00000
# ZTF J2252-05 b        ZTF J2252-05 b  26.0000       8.00000       8.00000
#
#                    mass_sin_i  mass_sin_i_err_min  mass_sin_i_err_max  radius  \
# name
# 109 Psc b              6.3830             0.07800             0.07800   1.152
# 112 Psc b              0.0330             0.00500             0.00500     NaN
# 112 Psc c                 NaN                 NaN                 NaN     NaN
# 11 Com Ab             16.1284             1.53491             1.53491     NaN
# 11 UMi b              11.0873             1.10000             1.10000     NaN
# ...                       ...                 ...                 ...     ...
# ZTF J0407-00 b            NaN                 NaN                 NaN   0.440
# ZTF J1406+1222 Ab         NaN                 NaN                 NaN   0.292
# ZTF J1622+47 b            NaN                 NaN                 NaN   0.980
# ZTF J1637+49 b            NaN                 NaN                 NaN   0.680
# ZTF J2252-05 b            NaN                 NaN                 NaN   0.490
#
#                    radius_err_min  radius_err_max  ...  star_dist_err_max  \
# name                                               ...
# 109 Psc b                     NaN             NaN  ...            0.88000
# 112 Psc b                     NaN             NaN  ...            0.10695
# 112 Psc c                     NaN             NaN  ...            0.10695
# 11 Com Ab                     NaN             NaN  ...           10.50000
# 11 UMi b                      NaN             NaN  ...            6.90000
# ...                           ...             ...  ...                ...
# ZTF J0407-00 b               0.02            0.02  ...          230.00000
# ZTF J1406+1222 Ab             NaN             NaN  ...          200.00000
# ZTF J1622+47 b               0.02            0.02  ...                NaN
# ZTF J1637+49 b               0.07            0.07  ...            8.00000
# ZTF J2252-05 b               0.04            0.04  ...           93.00000
#
#                    star_mass  star_mass_err_min  star_mass_err_max  \
# name
# 109 Psc b               1.13              0.030              0.030
# 112 Psc b               1.10              0.133              0.133
# 112 Psc c               1.10              0.133              0.133
# 11 Com Ab               2.70              0.300              0.300
# 11 UMi b                1.80              0.250              0.250
# ...                      ...                ...                ...
# ZTF J0407-00 b          0.79              0.060              0.060
# ZTF J1406+1222 Ab       1.40                NaN                NaN
# ZTF J1622+47 b          0.47                NaN                NaN
# ZTF J1637+49 b          0.90              0.050              0.050
# ZTF J2252-05 b          0.76              0.050              0.050
#
#                    star_radius  star_radius_err_min  star_radius_err_max  \
# name
# 109 Psc b              1.79000               0.1700               0.1700
# 112 Psc b              1.80100               0.0725               0.0725
# 112 Psc c              1.80100               0.0725               0.0725
# 11 Com Ab             19.00000               2.0000               2.0000
# 11 UMi b              24.08000               1.8400               1.8400
# ...                        ...                  ...                  ...
# ZTF J0407-00 b         0.01000               0.0010               0.0010
# ZTF J1406+1222 Ab      0.00002                  NaN                  NaN
# ZTF J1622+47 b         0.18200               0.0040               0.0040
# ZTF J1637+49 b         0.00900               0.0010               0.0010
# ZTF J2252-05 b         0.01000               0.0010               0.0010
#
#                             n     n_err_min     n_err_max
# name
# 109 Psc b            0.005843      8.975979      8.975979
# 112 Psc b            1.427997  15707.963268  15707.963268
# 112 Psc c            0.000173      0.001040      0.001040
# 11 Com Ab            0.019272     19.634954     19.634954
# 11 UMi b             0.012172      1.933288      1.933288
# ...                       ...           ...           ...
# ZTF J0407-00 b     255.414037           NaN           NaN
# ZTF J1406+1222 Ab  116.233408           NaN           NaN
# ZTF J1622+47 b      90.031428           NaN           NaN
# ZTF J1637+49 b     146.120589           NaN           NaN
# ZTF J2252-05 b     261.799388           NaN           NaN

# %% [markdown]
# Now, the dataset will be loaded from memory, instead of reading the file again.

# %%
eu = datasets.load_eu()
eu
# Out:
#  Loaded full dataset from memory stored datasets.
# Full ResokitDataset - 7407 rows x 45 columns
# Source: eu
# Age: 9 days
# Origin: zip
#                                 name     mass  mass_err_min  mass_err_max  \
# name
# 109 Psc b                  109 Psc b   5.7430       0.28900       0.28900
# 112 Psc b                  112 Psc b   0.0330       0.00500       0.00500
# 112 Psc c                  112 Psc c   9.8660       1.78100       1.78100
# 11 Com Ab                  11 Com Ab  16.1284       1.53491       1.53491
# 11 UMi b                    11 UMi b  11.0873       1.10000       1.10000
# ...                              ...      ...           ...           ...
# ZTF J0407-00 b        ZTF J0407-00 b  19.0000       3.00000       3.00000
# ZTF J1406+1222 Ab  ZTF J1406+1222 Ab  50.0000           NaN           NaN
# ZTF J1622+47 b        ZTF J1622+47 b  61.0000      19.00000      19.00000
# ZTF J1637+49 b        ZTF J1637+49 b  23.0000       8.00000       8.00000
# ZTF J2252-05 b        ZTF J2252-05 b  26.0000       8.00000       8.00000
#
#                    mass_sin_i  mass_sin_i_err_min  mass_sin_i_err_max  radius  \
# name
# 109 Psc b              6.3830             0.07800             0.07800   1.152
# 112 Psc b              0.0330             0.00500             0.00500     NaN
# 112 Psc c                 NaN                 NaN                 NaN     NaN
# 11 Com Ab             16.1284             1.53491             1.53491     NaN
# 11 UMi b              11.0873             1.10000             1.10000     NaN
# ...                       ...                 ...                 ...     ...
# ZTF J0407-00 b            NaN                 NaN                 NaN   0.440
# ZTF J1406+1222 Ab         NaN                 NaN                 NaN   0.292
# ZTF J1622+47 b            NaN                 NaN                 NaN   0.980
# ZTF J1637+49 b            NaN                 NaN                 NaN   0.680
# ZTF J2252-05 b            NaN                 NaN                 NaN   0.490
#
#                    radius_err_min  radius_err_max  ...  star_dist_err_max  \
# name                                               ...
# 109 Psc b                     NaN             NaN  ...            0.88000
# 112 Psc b                     NaN             NaN  ...            0.10695
# 112 Psc c                     NaN             NaN  ...            0.10695
# 11 Com Ab                     NaN             NaN  ...           10.50000
# 11 UMi b                      NaN             NaN  ...            6.90000
# ...                           ...             ...  ...                ...
# ZTF J0407-00 b               0.02            0.02  ...          230.00000
# ZTF J1406+1222 Ab             NaN             NaN  ...          200.00000
# ZTF J1622+47 b               0.02            0.02  ...                NaN
# ZTF J1637+49 b               0.07            0.07  ...            8.00000
# ZTF J2252-05 b               0.04            0.04  ...           93.00000
#
#                    star_mass  star_mass_err_min  star_mass_err_max  \
# name
# 109 Psc b               1.13              0.030              0.030
# 112 Psc b               1.10              0.133              0.133
# 112 Psc c               1.10              0.133              0.133
# 11 Com Ab               2.70              0.300              0.300
# 11 UMi b                1.80              0.250              0.250
# ...                      ...                ...                ...
# ZTF J0407-00 b          0.79              0.060              0.060
# ZTF J1406+1222 Ab       1.40                NaN                NaN
# ZTF J1622+47 b          0.47                NaN                NaN
# ZTF J1637+49 b          0.90              0.050              0.050
# ZTF J2252-05 b          0.76              0.050              0.050
#
#                    star_radius  star_radius_err_min  star_radius_err_max  \
# name
# 109 Psc b              1.79000               0.1700               0.1700
# 112 Psc b              1.80100               0.0725               0.0725
# 112 Psc c              1.80100               0.0725               0.0725
# 11 Com Ab             19.00000               2.0000               2.0000
# 11 UMi b              24.08000               1.8400               1.8400
# ...                        ...                  ...                  ...
# ZTF J0407-00 b         0.01000               0.0010               0.0010
# ZTF J1406+1222 Ab      0.00002                  NaN                  NaN
# ZTF J1622+47 b         0.18200               0.0040               0.0040
# ZTF J1637+49 b         0.00900               0.0010               0.0010
# ZTF J2252-05 b         0.01000               0.0010               0.0010
#
#                             n     n_err_min     n_err_max
# name
# 109 Psc b            0.005843      8.975979      8.975979
# 112 Psc b            1.427997  15707.963268  15707.963268
# 112 Psc c            0.000173      0.001040      0.001040
# 11 Com Ab            0.019272     19.634954     19.634954
# 11 UMi b             0.012172      1.933288      1.933288
# ...                       ...           ...           ...
# ZTF J0407-00 b     255.414037           NaN           NaN
# ZTF J1406+1222 Ab  116.233408           NaN           NaN
# ZTF J1622+47 b      90.031428           NaN           NaN
# ZTF J1637+49 b     146.120589           NaN           NaN
# ZTF J2252-05 b     261.799388           NaN           NaN

# %%
# Load NASA dataset too
nasa_full = datasets.load_nasa(store=True, check_age=True)

# Nasa dataset contains all exoplanet solutions (including non default and controversial), so we filter them here
nasa = nasa_full[(nasa_full.controversial == 0) & (nasa_full.default_set == 1)]
nasa
# Out:
#  Loading the entire dataset...
#   Reading nasa.csv directly from datasets.zip...
# Last modified: 2025-01-22 17:11:52 (9 days ago)
#  Updated stored index in memory.
#  Stored dataset in memory.
# Partial ResokitDataset - 5788 rows x 49 columns
# Source: nasa
# Age: 9 days
# Origin: zip
#                       name   star_name  default_set  \
# name
# Kepler-6 b      Kepler-6 b    Kepler-6            1
# Kepler-491 b  Kepler-491 b  Kepler-491            1
# Kepler-257 b  Kepler-257 b  Kepler-257            1
# Kepler-216 b  Kepler-216 b  Kepler-216            1
# Kepler-32 c    Kepler-32 c   Kepler-32            1
# ...                    ...         ...          ...
# Kepler-561 c  Kepler-561 c  Kepler-561            1
# Kepler-215 b  Kepler-215 b  Kepler-215            1
# Kepler-62 b    Kepler-62 b   Kepler-62            1
# Kepler-192 c  Kepler-192 c  Kepler-192            1
# Kepler-33 f    Kepler-33 f   Kepler-33            1
#
#                                                       reference  disc_year  \
# name
# Kepler-6 b    <a refstr=ESTEVES_ET_AL__2015 href=https://ui....       2009
# Kepler-491 b  <a refstr=MORTON_ET_AL__2016 href=https://ui.a...       2016
# Kepler-257 b  <a refstr=ROWE_ET_AL__2014 href=https://ui.ads...       2014
# Kepler-216 b  <a refstr=ROWE_ET_AL__2014 href=https://ui.ads...       2014
# Kepler-32 c   <a refstr=FABRYCKY_ET_AL__2012 href=https://ui...       2011
# ...                                                         ...        ...
# Kepler-561 c  <a refstr=MORTON_ET_AL__2016 href=https://ui.a...       2016
# Kepler-215 b  <a refstr=ROWE_ET_AL__2014 href=https://ui.ads...       2014
# Kepler-62 b   <a refstr=BORUCKI_ET_AL__2013 href=https://ui....       2013
# Kepler-192 c  <a refstr=ROWE_ET_AL__2014 href=https://ui.ads...       2014
# Kepler-33 f   <a refstr=LISSAUER_ET_AL__2012 href=https://ui...       2011
#
#              disc_method          P     P_err_min     P_err_max  w_err_min  \
# name
# Kepler-6 b       Transit   3.234700  4.000000e-07  4.000000e-07        NaN
# Kepler-491 b     Transit   4.225385  2.700000e-07  2.700000e-07        NaN
# Kepler-257 b     Transit   2.382667  6.000000e-06  6.000000e-06        NaN
# Kepler-216 b     Transit   7.693641  3.100000e-05  3.100000e-05        NaN
# Kepler-32 c      Transit   8.752200  3.000000e-04  3.000000e-04        NaN
# ...                  ...        ...           ...           ...        ...
# Kepler-561 c     Transit   5.350162  4.430000e-06  4.430000e-06        NaN
# Kepler-215 b     Transit   9.360672  4.000000e-05  4.000000e-05        NaN
# Kepler-62 b      Transit   5.714932  9.000000e-06  9.000000e-06        NaN
# Kepler-192 c     Transit  21.223400  7.600000e-05  7.600000e-05        NaN
# Kepler-33 f      Transit  41.029020  4.200000e-04  4.200000e-04        NaN
#
#               ...  star_radius_err_min  star_radius_err_max  n_stars  \
# name          ...
# Kepler-6 b    ...                 0.02                 0.03        1
# Kepler-491 b  ...                 0.09                 0.06        1
# Kepler-257 b  ...                 0.52                 0.52        1
# Kepler-216 b  ...                 0.24                 0.24        1
# Kepler-32 c   ...                 0.04                 0.04        1
# ...           ...                  ...                  ...      ...
# Kepler-561 c  ...                 0.16                 0.08        1
# Kepler-215 b  ...                 0.24                 0.24        1
# Kepler-62 b   ...                 0.02                 0.02        1
# Kepler-192 c  ...                 0.16                 0.16        1
# Kepler-33 f   ...                 0.14                 0.18        1
#
#               n_planets  star_dist  star_dist_err_min  star_dist_err_max  \
# name
# Kepler-6 b            1    587.039             5.0710             4.9860
# Kepler-491 b          1    630.785             6.4310             6.3050
# Kepler-257 b          3    780.256            17.5400            16.7990
# Kepler-216 b          2   1187.470            21.4200            21.4200
# Kepler-32 c           5    323.847             3.4025             3.4025
# ...                 ...        ...                ...                ...
# Kepler-561 c          2    621.378             9.3350             9.3350
# Kepler-215 b          4    485.997             3.6540             3.6540
# Kepler-62 b           5    300.874             1.2190             1.2190
# Kepler-192 c          3    651.674             6.7435             6.7435
# Kepler-33 f           5   1209.160            22.1950            22.1950
#
#                      n     n_err_min     n_err_max
# name
# Kepler-6 b    1.942432  1.570796e+07  1.570796e+07
# Kepler-491 b  1.487009  2.327106e+07  2.327106e+07
# Kepler-257 b  2.637039  1.047198e+06  1.047198e+06
# Kepler-216 b  0.816673  2.026834e+05  2.026834e+05
# Kepler-32 c   0.717898  2.094395e+04  2.094395e+04
# ...                ...           ...           ...
# Kepler-561 c  1.174392  1.418326e+06  1.418326e+06
# Kepler-215 b  0.671232  1.570796e+05  1.570796e+05
# Kepler-62 b   1.099433  6.981317e+05  6.981317e+05
# Kepler-192 c  0.296050  8.267349e+04  8.267349e+04
# Kepler-33 f   0.153140  1.495997e+04  1.495997e+04

# %% [markdown]
# We can see both datasets have different amount of exoplanets:

# %%
print(f"# of planets in NASA dataset: {nasa.shape[0]}")
print(f"# of planets in EU dataset: {eu.shape[0]}")
# Out:
# # of planets in NASA dataset: 5788
# # of planets in EU dataset: 7407

# %% [markdown]
# Checking the columns, we find that both data frames have almost all equal column names

# %%
print(f"{'Column':^19s} || {'NASA':^4s} | {'EU':^4s}")
print(f"{"-"*50}")
for col in nasa.columns.sort_values():
    print(f"{col:>19s} || {'YES':^4s} | {'YES' if col in eu.columns else 'NO':^4s}")
# Out:
#       Column        || NASA |  EU
# --------------------------------------------------
#                   P || YES  | YES
#           P_err_max || YES  | YES
#           P_err_min || YES  | YES
#                   a || YES  | YES
#           a_err_max || YES  | YES
#           a_err_min || YES  | YES
#       controversial || YES  |  NO
#         default_set || YES  |  NO
#         disc_method || YES  | YES
#           disc_year || YES  | YES
#                   e || YES  | YES
#           e_err_max || YES  | YES
#           e_err_min || YES  | YES
#                 inc || YES  | YES
#         inc_err_max || YES  | YES
#         inc_err_min || YES  | YES
#                mass || YES  | YES
#        mass_err_max || YES  | YES
#        mass_err_min || YES  | YES
#          mass_sin_i || YES  | YES
#  mass_sin_i_err_max || YES  | YES
#  mass_sin_i_err_min || YES  | YES
#                   n || YES  | YES
#           n_err_max || YES  | YES
#           n_err_min || YES  | YES
#           n_planets || YES  |  NO
#             n_stars || YES  |  NO
#                name || YES  | YES
#              radius || YES  | YES
#      radius_err_max || YES  | YES
#      radius_err_min || YES  | YES
#           reference || YES  | YES
#           rowupdate || YES  | YES
#           star_dist || YES  | YES
#   star_dist_err_max || YES  | YES
#   star_dist_err_min || YES  | YES
#           star_mass || YES  | YES
#   star_mass_err_max || YES  | YES
#   star_mass_err_min || YES  | YES
#           star_name || YES  | YES
#         star_radius || YES  | YES
# star_radius_err_max || YES  | YES
# star_radius_err_min || YES  | YES
#               tperi || YES  | YES
#       tperi_err_max || YES  | YES
#       tperi_err_min || YES  | YES
#                   w || YES  | YES
#           w_err_max || YES  | YES
#           w_err_min || YES  | YES

# %% [markdown]
# The only differences are:
# - controversial : The exoplanet is confirmed (0) or not yet (1).
# - default_set : The solution is the default set (1) or not (0).
# - n_planets : Amount of planets in that system.
# - n_stars : Amount of stars in that system.

# %% [markdown]
# We can see both datasets are similar, but not equal.

# %%
plt.figure(figsize=(5,4), dpi=130)
plt.plot(eu.mass, eu.radius, ".", ms=10, label="EU")
plt.plot(nasa.mass, nasa.radius, "x", ms=3, label="NASA")
plt.semilogx()
plt.semilogy()
plt.xlabel("Planet mass [M$_\\mathrm{J}$]")
plt.ylabel("Planet radius [R$_\\mathrm{J}$]")
plt.suptitle("Mass vs Radius comparison")
plt.xlim(1e-4, 1e2)
plt.ylim(bottom=1e-2)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5,4), dpi=130)
plt.plot(eu.a, eu.e, ".", ms=10, label="EU")
plt.plot(nasa.a, nasa.e, "x", ms=3, label="NASA")
plt.semilogx()
plt.semilogy()
plt.xlabel("Planet semimajor-axis [AU]")
plt.ylabel("Planet eccentricity")
plt.suptitle("$a$ vs $e$ comparison")
plt.ylim(bottom=1e-5)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Load full dataset
#
# Some planet and star data are not shown because the full data has been trimmed, when using `to_resokit=True` in `load` function.
#
# All data can be obtained using `to_resokit=False`. Moreover, if we wanted a `pandas Dataframe`, also use `to_df=True`. Nevertheless, in this case the column names will be the original from each database, instead of being mapped into more comprehensive ones.

# %%
nasa_original = datasets.load_nasa(to_resokit=False)
nasa_original
# Out:
#  Loaded full dataset from memory stored datasets.
# Full ResokitDataset - 38063 rows x 354 columns
# Source: nasa
# Age: 9 days
# Origin: zip
#            pl_name pl_letter   hostname hd_name hip_name         tic_id  \
# 0       Kepler-6 b         b   Kepler-6     NaN      NaN   TIC 27916356
# 1       Kepler-6 b         b   Kepler-6     NaN      NaN   TIC 27916356
# 2       Kepler-6 b         b   Kepler-6     NaN      NaN   TIC 27916356
# 3       Kepler-6 b         b   Kepler-6     NaN      NaN   TIC 27916356
# 4       Kepler-6 b         b   Kepler-6     NaN      NaN   TIC 27916356
# ...            ...       ...        ...     ...      ...            ...
# 38058  Kepler-33 f         f  Kepler-33     NaN      NaN  TIC 158935283
# 38059  Kepler-33 f         f  Kepler-33     NaN      NaN  TIC 158935283
# 38060  Kepler-33 f         f  Kepler-33     NaN      NaN  TIC 158935283
# 38061  Kepler-33 f         f  Kepler-33     NaN      NaN  TIC 158935283
# 38062  Kepler-33 f         f  Kepler-33     NaN      NaN  TIC 158935283
#
#                             gaia_id  default_flag  \
# 0      Gaia DR2 2086636884980514304             0
# 1      Gaia DR2 2086636884980514304             0
# 2      Gaia DR2 2086636884980514304             1
# 3      Gaia DR2 2086636884980514304             0
# 4      Gaia DR2 2086636884980514304             0
# ...                             ...           ...
# 38058  Gaia DR2 2127355923723254272             0
# 38059  Gaia DR2 2127355923723254272             1
# 38060  Gaia DR2 2127355923723254272             0
# 38061  Gaia DR2 2127355923723254272             0
# 38062  Gaia DR2 2127355923723254272             0
#
#                                               pl_refname  \
# 0      <a refstr=MORTON_ET_AL__2016 href=https://ui.a...
# 1      <a refstr=EXOFOP_TESS_TOI href=https://exofop....
# 2      <a refstr=ESTEVES_ET_AL__2015 href=https://ui....
# 3      <a refstr=Q1_Q12_KOI_TABLE href=https://exopla...
# 4      <a refstr=Q1_Q16_KOI_TABLE href=https://exopla...
# ...                                                  ...
# 38058  <a refstr=HOLCZER_ET_AL__2016 href=https://ui....
# 38059  <a refstr=LISSAUER_ET_AL__2012 href=https://ui...
# 38060  <a refstr=Q1_Q12_KOI_TABLE href=https://exopla...
# 38061  <a refstr=HADDEN_ET_AL__2014 href=https://ui.a...
# 38062  <a refstr=FULTON__AMP__PETIGURA_2018 href=http...
#
#                                               sy_refname  ... sy_jmagerr1  \
# 0      <a refstr=STASSUN_ET_AL__2019 href=https://ui....  ...       0.021
# 1      <a refstr=STASSUN_ET_AL__2019 href=https://ui....  ...       0.021
# 2      <a refstr=STASSUN_ET_AL__2019 href=https://ui....  ...       0.021
# 3      <a refstr=STASSUN_ET_AL__2019 href=https://ui....  ...       0.021
# 4      <a refstr=STASSUN_ET_AL__2019 href=https://ui....  ...       0.021
# ...                                                  ...  ...         ...
# 38058  <a refstr=STASSUN_ET_AL__2019 href=https://ui....  ...       0.020
# 38059  <a refstr=STASSUN_ET_AL__2019 href=https://ui....  ...       0.020
# 38060  <a refstr=STASSUN_ET_AL__2019 href=https://ui....  ...       0.020
# 38061  <a refstr=STASSUN_ET_AL__2019 href=https://ui....  ...       0.020
# 38062  <a refstr=STASSUN_ET_AL__2019 href=https://ui....  ...       0.020
#
#        sy_jmagerr2           sy_jmagstr sy_hmag sy_hmagerr1 sy_hmagerr2  \
# 0           -0.021  12.001&plusmn;0.021  11.706       0.019      -0.019
# 1           -0.021  12.001&plusmn;0.021  11.706       0.019      -0.019
# 2           -0.021  12.001&plusmn;0.021  11.706       0.019      -0.019
# 3           -0.021  12.001&plusmn;0.021  11.706       0.019      -0.019
# 4           -0.021  12.001&plusmn;0.021  11.706       0.019      -0.019
# ...            ...                  ...     ...         ...         ...
# 38058       -0.020  12.871&plusmn;0.020  12.620       0.021      -0.021
# 38059       -0.020  12.871&plusmn;0.020  12.620       0.021      -0.021
# 38060       -0.020  12.871&plusmn;0.020  12.620       0.021      -0.021
# 38061       -0.020  12.871&plusmn;0.020  12.620       0.021      -0.021
# 38062       -0.020  12.871&plusmn;0.020  12.620       0.021      -0.021
#
#                 sy_hmagstr sy_kmag  sy_kmagerr1 sy_kmagerr2
# 0      11.706&plusmn;0.019  11.634        0.019      -0.019
# 1      11.706&plusmn;0.019  11.634        0.019      -0.019
# 2      11.706&plusmn;0.019  11.634        0.019      -0.019
# 3      11.706&plusmn;0.019  11.634        0.019      -0.019
# 4      11.706&plusmn;0.019  11.634        0.019      -0.019
# ...                    ...     ...          ...         ...
# 38058  12.620&plusmn;0.021  12.591        0.022      -0.022
# 38059  12.620&plusmn;0.021  12.591        0.022      -0.022
# 38060  12.620&plusmn;0.021  12.591        0.022      -0.022
# 38061  12.620&plusmn;0.021  12.591        0.022      -0.022
# 38062  12.620&plusmn;0.021  12.591        0.022      -0.022

# %% [markdown]
# We see that the amount of columns is larger than before

# %%
print("# of columns in nasa (to_resokit=True):", nasa.shape[1])
print("# of columns in nasa (to_resokit=False):", nasa_original.shape[1])
# Out:
# # of columns in nasa (to_resokit=True): 49
# # of columns in nasa (to_resokit=False): 354

# %% [markdown]
# Also, we can see that **mass** or **radius** are not in the dataframe, but it has **`pl_massj`** and **`pl_radj`** instead.

# %%
print("'mass' in nasa_original:", "mass" in nasa_original.columns)
print("'radius' in nasa_original:", "radius" in nasa_original.columns)

print("'pl_massj' in nasa_original:", "pl_massj" in nasa_original.columns)
print("'pl_radj' in nasa_original:", "pl_radj" in nasa_original.columns)
# Out:
# 'mass' in nasa_original: False
# 'radius' in nasa_original: False
# 'pl_massj' in nasa_original: True
# 'pl_radj' in nasa_original: True

# %% [markdown]
# ## Default units
#
# More information about the units can be found at:
# - EU: [https://exoplanet.eu/readme/](https://exoplanet.eu/readme/)
# - NASA: [https://exoplanetarchive.ipac.caltech.edu/docs/API_PS_columns.html](https://exoplanetarchive.ipac.caltech.edu/docs/API_PS_columns.html)
#
# but the basics are:
#
# - Planet:
#     - mass: Jupiter masses
#     - radius: Jupiter radii
#     - semimajor-axes: au
#
# - Star:
#     - mass: Solar masses
#     - radius: Solar radii
#     - distance: Parsecs

# %% [markdown]
# ## Update
#
#
# When loading a dataset, we can set `check_age=True` to get info about when the dataset was updated.

# %%
datasets.load_eu(check_age=True)
# Out:
#  Loaded full dataset from memory stored datasets.
# Last modified: 9 days ago
# Full ResokitDataset - 7407 rows x 45 columns
# Source: eu
# Age: 9 days
# Origin: zip
#                                 name     mass  mass_err_min  mass_err_max  \
# name
# 109 Psc b                  109 Psc b   5.7430       0.28900       0.28900
# 112 Psc b                  112 Psc b   0.0330       0.00500       0.00500
# 112 Psc c                  112 Psc c   9.8660       1.78100       1.78100
# 11 Com Ab                  11 Com Ab  16.1284       1.53491       1.53491
# 11 UMi b                    11 UMi b  11.0873       1.10000       1.10000
# ...                              ...      ...           ...           ...
# ZTF J0407-00 b        ZTF J0407-00 b  19.0000       3.00000       3.00000
# ZTF J1406+1222 Ab  ZTF J1406+1222 Ab  50.0000           NaN           NaN
# ZTF J1622+47 b        ZTF J1622+47 b  61.0000      19.00000      19.00000
# ZTF J1637+49 b        ZTF J1637+49 b  23.0000       8.00000       8.00000
# ZTF J2252-05 b        ZTF J2252-05 b  26.0000       8.00000       8.00000
#
#                    mass_sin_i  mass_sin_i_err_min  mass_sin_i_err_max  radius  \
# name
# 109 Psc b              6.3830             0.07800             0.07800   1.152
# 112 Psc b              0.0330             0.00500             0.00500     NaN
# 112 Psc c                 NaN                 NaN                 NaN     NaN
# 11 Com Ab             16.1284             1.53491             1.53491     NaN
# 11 UMi b              11.0873             1.10000             1.10000     NaN
# ...                       ...                 ...                 ...     ...
# ZTF J0407-00 b            NaN                 NaN                 NaN   0.440
# ZTF J1406+1222 Ab         NaN                 NaN                 NaN   0.292
# ZTF J1622+47 b            NaN                 NaN                 NaN   0.980
# ZTF J1637+49 b            NaN                 NaN                 NaN   0.680
# ZTF J2252-05 b            NaN                 NaN                 NaN   0.490
#
#                    radius_err_min  radius_err_max  ...  star_dist_err_max  \
# name                                               ...
# 109 Psc b                     NaN             NaN  ...            0.88000
# 112 Psc b                     NaN             NaN  ...            0.10695
# 112 Psc c                     NaN             NaN  ...            0.10695
# 11 Com Ab                     NaN             NaN  ...           10.50000
# 11 UMi b                      NaN             NaN  ...            6.90000
# ...                           ...             ...  ...                ...
# ZTF J0407-00 b               0.02            0.02  ...          230.00000
# ZTF J1406+1222 Ab             NaN             NaN  ...          200.00000
# ZTF J1622+47 b               0.02            0.02  ...                NaN
# ZTF J1637+49 b               0.07            0.07  ...            8.00000
# ZTF J2252-05 b               0.04            0.04  ...           93.00000
#
#                    star_mass  star_mass_err_min  star_mass_err_max  \
# name
# 109 Psc b               1.13              0.030              0.030
# 112 Psc b               1.10              0.133              0.133
# 112 Psc c               1.10              0.133              0.133
# 11 Com Ab               2.70              0.300              0.300
# 11 UMi b                1.80              0.250              0.250
# ...                      ...                ...                ...
# ZTF J0407-00 b          0.79              0.060              0.060
# ZTF J1406+1222 Ab       1.40                NaN                NaN
# ZTF J1622+47 b          0.47                NaN                NaN
# ZTF J1637+49 b          0.90              0.050              0.050
# ZTF J2252-05 b          0.76              0.050              0.050
#
#                    star_radius  star_radius_err_min  star_radius_err_max  \
# name
# 109 Psc b              1.79000               0.1700               0.1700
# 112 Psc b              1.80100               0.0725               0.0725
# 112 Psc c              1.80100               0.0725               0.0725
# 11 Com Ab             19.00000               2.0000               2.0000
# 11 UMi b              24.08000               1.8400               1.8400
# ...                        ...                  ...                  ...
# ZTF J0407-00 b         0.01000               0.0010               0.0010
# ZTF J1406+1222 Ab      0.00002                  NaN                  NaN
# ZTF J1622+47 b         0.18200               0.0040               0.0040
# ZTF J1637+49 b         0.00900               0.0010               0.0010
# ZTF J2252-05 b         0.01000               0.0010               0.0010
#
#                             n     n_err_min     n_err_max
# name
# 109 Psc b            0.005843      8.975979      8.975979
# 112 Psc b            1.427997  15707.963268  15707.963268
# 112 Psc c            0.000173      0.001040      0.001040
# 11 Com Ab            0.019272     19.634954     19.634954
# 11 UMi b             0.012172      1.933288      1.933288
# ...                       ...           ...           ...
# ZTF J0407-00 b     255.414037           NaN           NaN
# ZTF J1406+1222 Ab  116.233408           NaN           NaN
# ZTF J1622+47 b      90.031428           NaN           NaN
# ZTF J1637+49 b     146.120589           NaN           NaN
# ZTF J2252-05 b     261.799388           NaN           NaN

# %% [markdown]
# To perform a dataset update, we can use the function `update_eu` or `update_nasa`; or the main function `download`.

# %%
datasets.download?
# Out:
# Signature:
# datasets.download(
#     source: str,
#     dir_path: Union[str, pathlib.Path, NoneType] = None,
#     to_file: Union[str, pathlib.Path, bool, NoneType] = False,
#     to_zip: Union[str, pathlib.Path, bool, NoneType] = False,
#     to_memory: bool = True,
#     overwrite: bool = False,
#     verbose: bool = True,
#     to_resokit: Optional[bool] = None,
#     chunk_size: int = 1024,
#     print_size: float = 0.15,
# ) -> Union[pathlib.Path, pandas.core.frame.DataFrame, resokit.datasets.databases.ResoKitDataset]
# Docstring:
# Download a dataset from a specified source and save it locally.
#
# The dataset is downloaded from the internet, from the online NASA
# or exoplanet.eu databases, and can be stored in a file, a ZIP archive,
# in memory, and/or simply returned.
#
# Note
# ----
# Requires the requests library.
#
# Parameters
# ----------
# source : str
#     Identifier for the data source ('eu' or 'nasa').
# dir_path : str or Path
#     Directory path to save the dataset, or path to the ZIP archive.
#     If `None`, the default directory is used (resokit.datasets).
# to_file : str or Path or bool, optional. Default: False.
#     Path or str to the file to store the dataset.
#     If `True`, default filename is used.
#     If `False`, the file is not saved nor created.
# to_zip : str or Path or bool, optional. Default: False.
#     Path or str to the ZIP archive to store the dataset.
#     If `True`, default ZIP filename is used. (datasets.zip)
#     If `False`, the file is not saved nor created in the ZIP archive.
# to_memory : bool, optional. Default: False.
#     If `True`, stores the dataset in memory.
# overwrite : bool, optional. Default: False.
#     If `True`, overwrites the file if it already exists.
#     It also overwrites the stored dataset in memory.
# verbose : bool, optional. Default: True.
#     If `True`, displays messages about the download process.
# to_resokit : bool, dict, optional. Default: None.
#     If `True`, returns the dataset as a ResoKitDataset.
#     If `False`, returns the dataset as a pandas DataFrame.
#     If `None`, returns the path to the downloaded file.
# chunk_size : int, optional. Default: 1024.
#     Size of the chunks to download the dataset, in bytes.
#     Default is 1024 bytes (1 KB).
# print_size: float, optional. Default: 0.15.
#     Update frequency for the download progress bar.
#
# Returns
# -------
# downloaded : Path or pd.DataFrame or None
#     `Path` to the downloaded dataset (and or zip archive),
#     or the dataset if `to_resokit` is not `None`.
# File:      ~/Documentos/git/ResoKit/resokit/datasets/databases.py
# Type:      function

# %% [markdown]
# To download an update EU database, and store it as a .csv we simply run

# %%
data = datasets.download("eu", to_file="/tmp/new_eu.csv", to_resokit=True)
data
# Out:
#  Downloading data from https://exoplanet.eu/catalog/csv/...
#  Note: Progress is shown at every 0.15 MB
#  Data downloaded successfully. (3.31 MB)
#  Creating the file /tmp/new_eu.csv...
#  Written /tmp/new_eu.csv.
# Full ResokitDataset - 7409 rows x 45 columns
# Source: eu
# Age: 0 days
# Origin: internet
#                                 name     mass  mass_err_min  mass_err_max  \
# name
# 109 Psc b                  109 Psc b   5.7430       0.28900       0.28900
# 112 Psc b                  112 Psc b   0.0330       0.00500       0.00500
# 112 Psc c                  112 Psc c   9.8660       1.78100       1.78100
# 11 Com Ab                  11 Com Ab  16.1284       1.53491       1.53491
# 11 UMi b                    11 UMi b  11.0873       1.10000       1.10000
# ...                              ...      ...           ...           ...
# ZTF J1406+1222 Ab  ZTF J1406+1222 Ab  50.0000           NaN           NaN
# ZTF J1622+47 b        ZTF J1622+47 b  61.0000      19.00000      19.00000
# ZTF J1637+49 b        ZTF J1637+49 b  23.0000       8.00000       8.00000
# ZTF J1828+2308 b    ZTF J1828+2308 b  19.5000       0.80000       0.80000
# ZTF J2252-05 b        ZTF J2252-05 b  26.0000       8.00000       8.00000
#
#                    mass_sin_i  mass_sin_i_err_min  mass_sin_i_err_max  radius  \
# name
# 109 Psc b              6.3830             0.07800             0.07800   1.152
# 112 Psc b              0.0330             0.00500             0.00500     NaN
# 112 Psc c                 NaN                 NaN                 NaN     NaN
# 11 Com Ab             16.1284             1.53491             1.53491     NaN
# 11 UMi b              11.0873             1.10000             1.10000     NaN
# ...                       ...                 ...                 ...     ...
# ZTF J1406+1222 Ab         NaN                 NaN                 NaN   0.292
# ZTF J1622+47 b            NaN                 NaN                 NaN   0.980
# ZTF J1637+49 b            NaN                 NaN                 NaN   0.680
# ZTF J1828+2308 b          NaN                 NaN                 NaN   1.020
# ZTF J2252-05 b            NaN                 NaN                 NaN   0.490
#
#                    radius_err_min  radius_err_max  ...  star_dist_err_max  \
# name                                               ...
# 109 Psc b                     NaN             NaN  ...            0.88000
# 112 Psc b                     NaN             NaN  ...            0.10695
# 112 Psc c                     NaN             NaN  ...            0.10695
# 11 Com Ab                     NaN             NaN  ...           10.50000
# 11 UMi b                      NaN             NaN  ...            6.90000
# ...                           ...             ...  ...                ...
# ZTF J1406+1222 Ab             NaN             NaN  ...          200.00000
# ZTF J1622+47 b               0.02            0.02  ...                NaN
# ZTF J1637+49 b               0.07            0.07  ...            8.00000
# ZTF J1828+2308 b             0.02            0.02  ...            5.00000
# ZTF J2252-05 b               0.04            0.04  ...           93.00000
#
#                    star_mass  star_mass_err_min  star_mass_err_max  \
# name
# 109 Psc b               1.13              0.030              0.030
# 112 Psc b               1.10              0.133              0.133
# 112 Psc c               1.10              0.133              0.133
# 11 Com Ab               2.70              0.300              0.300
# 11 UMi b                1.80              0.250              0.250
# ...                      ...                ...                ...
# ZTF J1406+1222 Ab       1.40                NaN                NaN
# ZTF J1622+47 b          0.47                NaN                NaN
# ZTF J1637+49 b          0.90              0.050              0.050
# ZTF J1828+2308 b        0.61              0.040              0.040
# ZTF J2252-05 b          0.76              0.050              0.050
#
#                    star_radius  star_radius_err_min  star_radius_err_max  \
# name
# 109 Psc b              1.79000               0.1700               0.1700
# 112 Psc b              1.80100               0.0725               0.0725
# 112 Psc c              1.80100               0.0725               0.0725
# 11 Com Ab             19.00000               2.0000               2.0000
# 11 UMi b              24.08000               1.8400               1.8400
# ...                        ...                  ...                  ...
# ZTF J1406+1222 Ab      0.00002                  NaN                  NaN
# ZTF J1622+47 b         0.18200               0.0040               0.0040
# ZTF J1637+49 b         0.00900               0.0010               0.0010
# ZTF J1828+2308 b       0.01310               0.0002               0.0002
# ZTF J2252-05 b         0.01000               0.0010               0.0010
#
#                             n     n_err_min     n_err_max
# name
# 109 Psc b            0.005843  8.975979e+00  8.975979e+00
# 112 Psc b            1.427997  1.570796e+04  1.570796e+04
# 112 Psc c            0.000173  1.040366e-03  1.040366e-03
# 11 Com Ab            0.019272  1.963495e+01  1.963495e+01
# 11 UMi b             0.012172  1.933288e+00  1.933288e+00
# ...                       ...           ...           ...
# ZTF J1406+1222 Ab  116.233408           NaN           NaN
# ZTF J1622+47 b      90.031428           NaN           NaN
# ZTF J1637+49 b     146.120589           NaN           NaN
# ZTF J1828+2308 b    56.096513  7.222052e+06  7.222052e+06
# ZTF J2252-05 b     261.799388           NaN           NaN

# %% [markdown]
# To replace a file just use `overwrite=True`, even to replace the file inside datasets.zip (`to_zip=True`).
